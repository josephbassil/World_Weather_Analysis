# %%
import requests
import numpy as np
import pandas as pd
from citipy import citipy
from datetime import datetime

# %%
lats=np.random.uniform(-90,90,size=2000)
lngs=np.random.uniform(-180,180,size=2000)
lat_lngs=zip(lats,lngs)
coordinates=list(lat_lngs)

# %%
cities=[]

for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 810

# %%
#API
from config import weather_api_key
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

#city_url=url+"&q="+" "
#city_weather=requests.get(city_url)

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 1 | primo tapia
# Processing Record 3 of Set 1 | kang
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | victoria
# Processing Record 7 of Set 1 | hithadhoo
# Processing Record 8 of Set 1 | sao joao da barra
# Processing Record 9 of Set 1 | bertoua
# Processing Record 10 of Set 1 | menongue
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | kysyl-syr
# Processing Record 13 of Set 1 | cape town
# Processing Record 14 of Set 1 | clyde river
# Processing Record 15 of Set 1 | pochutla
# Processing Record 16 of Set 1 | mashhad
# Processing Record 17 of Set 1 | tiksi
# Processing Record 18 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 1 | chokurdakh
# Processing Record 20 of Set 1 | nikolskoye
# Processing Record 21 of Set 1 | gazanjyk
# Processing Record 22 of Set 1 | naze
# Processing Record 23 of Set 1 | mount gambier
# Processing Record 24 of Set 1 | butaritari
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 27 of Set 1 | port lincoln
# Processing Record 28 of Set 1 | daman
# Processing Record 29 of Set 1 | mahebourg
# Processing Record 30 of Set 1 | avarua
# Processing Record 31 of Set 1 | thompson
# Processing Record 32 of Set 1 | tasiilaq
# Processing Record 33 of Set 1 | kapaa
# Processing Record 34 of Set 1 | conceicao do araguaia
# Processing Record 35 of Set 1 | cidreira
# Processing Record 36 of Set 1 | souillac
# Processing Record 37 of Set 1 | san blas
# Processing Record 38 of Set 1 | mandera
# Processing Record 39 of Set 1 | zhenhai
# Processing Record 40 of Set 1 | yellowknife
# Processing Record 41 of Set 1 | saint george
# Processing Record 42 of Set 1 | salinopolis
# Processing Record 43 of Set 1 | opuwo
# Processing Record 44 of Set 1 | berck
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 1 | atuona
# Processing Record 48 of Set 1 | vaini
# Processing Record 49 of Set 1 | tiarei
# Processing Record 50 of Set 1 | bredasdorp
# Processing Record 1 of Set 2 | bambous virieux
# Processing Record 2 of Set 2 | bethel
# Processing Record 3 of Set 2 | hobart
# Processing Record 4 of Set 2 | ternate
# Processing Record 5 of Set 2 | kunming
# Processing Record 6 of Set 2 | port shepstone
# Processing Record 7 of Set 2 | chuy
# Processing Record 8 of Set 2 | kaitangata
# Processing Record 9 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 2 | praia da vitoria
# Processing Record 11 of Set 2 | kruisfontein
# Processing Record 12 of Set 2 | maridi
# Processing Record 13 of Set 2 | huarmey
# Processing Record 14 of Set 2 | punta arenas
# Processing Record 15 of Set 2 | san jeronimo
# Processing Record 16 of Set 2 | mackay
# Processing Record 17 of Set 2 | srandakan
# Processing Record 18 of Set 2 | castro
# Processing Record 19 of Set 2 | saint-philippe
# Processing Record 20 of Set 2 | nampula
# Processing Record 21 of Set 2 | padang
# Processing Record 22 of Set 2 | dikson
# Processing Record 23 of Set 2 | hilo
# Processing Record 24 of Set 2 | carutapera
# Processing Record 25 of Set 2 | satitoa
# City not found. Skipping...
# Processing Record 26 of Set 2 | vasteras
# Processing Record 27 of Set 2 | nauta
# Processing Record 28 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 2 | lavrentiya
# Processing Record 30 of Set 2 | emerald
# Processing Record 31 of Set 2 | ostrovnoy
# Processing Record 32 of Set 2 | sioux lookout
# Processing Record 33 of Set 2 | corinto
# Processing Record 34 of Set 2 | bluff
# Processing Record 35 of Set 2 | luderitz
# Processing Record 36 of Set 2 | husavik
# Processing Record 37 of Set 2 | maniitsoq
# Processing Record 38 of Set 2 | saskylakh
# Processing Record 39 of Set 2 | puerto ayora
# Processing Record 40 of Set 2 | belmonte
# Processing Record 41 of Set 2 | snezhnogorsk
# Processing Record 42 of Set 2 | changping
# Processing Record 43 of Set 2 | khatanga
# Processing Record 44 of Set 2 | arraial do cabo
# Processing Record 45 of Set 2 | tuktoyaktuk
# Processing Record 46 of Set 2 | siswa bazar
# Processing Record 47 of Set 2 | soller
# Processing Record 48 of Set 2 | winnemucca
# Processing Record 49 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 2 | derbent
# Processing Record 1 of Set 3 | tuatapere
# Processing Record 2 of Set 3 | port keats
# Processing Record 3 of Set 3 | samarai
# Processing Record 4 of Set 3 | inderborskiy
# City not found. Skipping...
# Processing Record 5 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 6 of Set 3 | wenling
# Processing Record 7 of Set 3 | hermanus
# Processing Record 8 of Set 3 | hasaki
# Processing Record 9 of Set 3 | along
# Processing Record 10 of Set 3 | uberlandia
# Processing Record 11 of Set 3 | novomichurinsk
# Processing Record 12 of Set 3 | codrington
# Processing Record 13 of Set 3 | lagoa
# Processing Record 14 of Set 3 | zhangjiakou
# Processing Record 15 of Set 3 | port alfred
# Processing Record 16 of Set 3 | nanortalik
# Processing Record 17 of Set 3 | upernavik
# Processing Record 18 of Set 3 | mezen
# Processing Record 19 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 3 | curuca
# Processing Record 21 of Set 3 | ler
# Processing Record 22 of Set 3 | asekeyevo
# Processing Record 23 of Set 3 | klaksvik
# Processing Record 24 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 25 of Set 3 | srednekolymsk
# Processing Record 26 of Set 3 | qaanaaq
# Processing Record 27 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 3 | naron
# Processing Record 29 of Set 3 | provideniya
# Processing Record 30 of Set 3 | arman
# Processing Record 31 of Set 3 | sao filipe
# Processing Record 32 of Set 3 | airai
# Processing Record 33 of Set 3 | ponta do sol
# Processing Record 34 of Set 3 | east london
# Processing Record 35 of Set 3 | longyearbyen
# Processing Record 36 of Set 3 | broome
# Processing Record 37 of Set 3 | mataram
# Processing Record 38 of Set 3 | kodiak
# Processing Record 39 of Set 3 | ponta delgada
# Processing Record 40 of Set 3 | rantepao
# Processing Record 41 of Set 3 | saint anthony
# Processing Record 42 of Set 3 | roald
# Processing Record 43 of Set 3 | albany
# Processing Record 44 of Set 3 | caravelas
# Processing Record 45 of Set 3 | pisco
# Processing Record 46 of Set 3 | whitefish
# Processing Record 47 of Set 3 | tucumcari
# Processing Record 48 of Set 3 | coquimbo
# Processing Record 49 of Set 3 | boende
# Processing Record 50 of Set 3 | pacific grove
# Processing Record 1 of Set 4 | port elizabeth
# Processing Record 2 of Set 4 | sola
# Processing Record 3 of Set 4 | hvammstangi
# City not found. Skipping...
# Processing Record 4 of Set 4 | pimenta bueno
# Processing Record 5 of Set 4 | kidal
# Processing Record 6 of Set 4 | barrow
# Processing Record 7 of Set 4 | gushikawa
# Processing Record 8 of Set 4 | talnakh
# Processing Record 9 of Set 4 | anadyr
# Processing Record 10 of Set 4 | mumbwa
# Processing Record 11 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 4 | lebu
# Processing Record 13 of Set 4 | salalah
# Processing Record 14 of Set 4 | new norfolk
# Processing Record 15 of Set 4 | kabompo
# Processing Record 16 of Set 4 | hofn
# Processing Record 17 of Set 4 | ribeira grande
# Processing Record 18 of Set 4 | mareeba
# Processing Record 19 of Set 4 | roma
# Processing Record 20 of Set 4 | ahipara
# Processing Record 21 of Set 4 | ojinaga
# Processing Record 22 of Set 4 | willowmore
# Processing Record 23 of Set 4 | gambela
# Processing Record 24 of Set 4 | mayahi
# Processing Record 25 of Set 4 | vestmannaeyjar
# Processing Record 26 of Set 4 | singaparna
# Processing Record 27 of Set 4 | azangaro
# Processing Record 28 of Set 4 | luena
# Processing Record 29 of Set 4 | valdivia
# Processing Record 30 of Set 4 | faanui
# Processing Record 31 of Set 4 | kushima
# Processing Record 32 of Set 4 | pevek
# Processing Record 33 of Set 4 | aginskoye
# Processing Record 34 of Set 4 | mar del plata
# Processing Record 35 of Set 4 | limon
# Processing Record 36 of Set 4 | norman wells
# Processing Record 37 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 38 of Set 4 | gimli
# Processing Record 39 of Set 4 | kermanshah
# Processing Record 40 of Set 4 | constitucion
# Processing Record 41 of Set 4 | mogadishu
# Processing Record 42 of Set 4 | chara
# Processing Record 43 of Set 4 | yulara
# Processing Record 44 of Set 4 | west fargo
# Processing Record 45 of Set 4 | marzuq
# Processing Record 46 of Set 4 | neuquen
# Processing Record 47 of Set 4 | chisec
# Processing Record 48 of Set 4 | cabra
# Processing Record 49 of Set 4 | bengkulu
# Processing Record 50 of Set 4 | yeppoon
# Processing Record 1 of Set 5 | iqaluit
# Processing Record 2 of Set 5 | waipawa
# Processing Record 3 of Set 5 | khon buri
# Processing Record 4 of Set 5 | kaeo
# Processing Record 5 of Set 5 | lakes entrance
# Processing Record 6 of Set 5 | xining
# Processing Record 7 of Set 5 | fortuna
# Processing Record 8 of Set 5 | leningradskiy
# Processing Record 9 of Set 5 | rocha
# Processing Record 10 of Set 5 | hualmay
# Processing Record 11 of Set 5 | sangar
# Processing Record 12 of Set 5 | victor harbor
# Processing Record 13 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 14 of Set 5 | pizhanka
# Processing Record 15 of Set 5 | mulchen
# Processing Record 16 of Set 5 | carnarvon
# Processing Record 17 of Set 5 | cayenne
# Processing Record 18 of Set 5 | kokkola
# Processing Record 19 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 5 | wawa
# Processing Record 21 of Set 5 | nortelandia
# Processing Record 22 of Set 5 | yenagoa
# Processing Record 23 of Set 5 | udimskiy
# Processing Record 24 of Set 5 | havre-saint-pierre
# Processing Record 25 of Set 5 | namibe
# Processing Record 26 of Set 5 | pandan
# Processing Record 27 of Set 5 | praya
# Processing Record 28 of Set 5 | campbell river
# Processing Record 29 of Set 5 | rawson
# Processing Record 30 of Set 5 | georgiyevka
# Processing Record 31 of Set 5 | mocuba
# Processing Record 32 of Set 5 | aviles
# Processing Record 33 of Set 5 | caldwell
# Processing Record 34 of Set 5 | viedma
# Processing Record 35 of Set 5 | georgetown
# Processing Record 36 of Set 5 | torbay
# Processing Record 37 of Set 5 | camacha
# Processing Record 38 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 5 | aripuana
# Processing Record 40 of Set 5 | ranong
# Processing Record 41 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 42 of Set 5 | cabo san lucas
# Processing Record 43 of Set 5 | balabac
# Processing Record 44 of Set 5 | chadiza
# Processing Record 45 of Set 5 | bubaque
# Processing Record 46 of Set 5 | puerto escondido
# Processing Record 47 of Set 5 | pau
# Processing Record 48 of Set 5 | seymchan
# Processing Record 49 of Set 5 | itanhem
# Processing Record 50 of Set 5 | kavieng
# Processing Record 1 of Set 6 | flinders
# Processing Record 2 of Set 6 | manokwari
# Processing Record 3 of Set 6 | nizhnevartovsk
# Processing Record 4 of Set 6 | ingham
# Processing Record 5 of Set 6 | okato
# Processing Record 6 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 6 | kitimat
# Processing Record 8 of Set 6 | biloela
# Processing Record 9 of Set 6 | novikovo
# Processing Record 10 of Set 6 | kamphaeng phet
# Processing Record 11 of Set 6 | marsh harbour
# Processing Record 12 of Set 6 | greenwood
# Processing Record 13 of Set 6 | drayton valley
# Processing Record 14 of Set 6 | faya
# Processing Record 15 of Set 6 | kirakira
# Processing Record 16 of Set 6 | cockburn town
# Processing Record 17 of Set 6 | muros
# Processing Record 18 of Set 6 | grants pass
# Processing Record 19 of Set 6 | kenora
# Processing Record 20 of Set 6 | blagoyevo
# Processing Record 21 of Set 6 | fairbanks
# Processing Record 22 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 23 of Set 6 | east wenatchee bench
# Processing Record 24 of Set 6 | brainerd
# Processing Record 25 of Set 6 | shakiso
# Processing Record 26 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 27 of Set 6 | arvika
# Processing Record 28 of Set 6 | verkhnyaya inta
# Processing Record 29 of Set 6 | praia
# Processing Record 30 of Set 6 | bereda
# Processing Record 31 of Set 6 | aasiaat
# Processing Record 32 of Set 6 | vardo
# Processing Record 33 of Set 6 | beringovskiy
# Processing Record 34 of Set 6 | goksun
# Processing Record 35 of Set 6 | yerofey pavlovich
# Processing Record 36 of Set 6 | hals
# Processing Record 37 of Set 6 | tilichiki
# Processing Record 38 of Set 6 | kieta
# Processing Record 39 of Set 6 | chernyshevskiy
# Processing Record 40 of Set 6 | bilma
# Processing Record 41 of Set 6 | sumter
# Processing Record 42 of Set 6 | sobolevo
# Processing Record 43 of Set 6 | luancheng
# Processing Record 44 of Set 6 | gweta
# Processing Record 45 of Set 6 | komsomolskiy
# Processing Record 46 of Set 6 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 47 of Set 6 | encruzilhada do sul
# Processing Record 48 of Set 6 | wajima
# Processing Record 49 of Set 6 | buritis
# Processing Record 50 of Set 6 | virginia beach
# Processing Record 1 of Set 7 | ejido
# Processing Record 2 of Set 7 | makat
# Processing Record 3 of Set 7 | loandjili
# Processing Record 4 of Set 7 | portland
# Processing Record 5 of Set 7 | avera
# Processing Record 6 of Set 7 | sovetskiy
# Processing Record 7 of Set 7 | yerbogachen
# Processing Record 8 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 7 | sinkat
# City not found. Skipping...
# Processing Record 10 of Set 7 | nelson bay
# Processing Record 11 of Set 7 | mollendo
# Processing Record 12 of Set 7 | vanimo
# Processing Record 13 of Set 7 | huainan
# Processing Record 14 of Set 7 | tacoronte
# Processing Record 15 of Set 7 | hirara
# Processing Record 16 of Set 7 | verkhovazhye
# Processing Record 17 of Set 7 | cherskiy
# Processing Record 18 of Set 7 | chumikan
# Processing Record 19 of Set 7 | yicheng
# Processing Record 20 of Set 7 | tacuati
# Processing Record 21 of Set 7 | chicaman
# Processing Record 22 of Set 7 | rosetta
# Processing Record 23 of Set 7 | riverton
# Processing Record 24 of Set 7 | hervey bay
# Processing Record 25 of Set 7 | narsaq
# Processing Record 26 of Set 7 | piacabucu
# Processing Record 27 of Set 7 | lannion
# Processing Record 28 of Set 7 | san patricio
# Processing Record 29 of Set 7 | tungor
# Processing Record 30 of Set 7 | sitka
# Processing Record 31 of Set 7 | russell
# Processing Record 32 of Set 7 | yumen
# Processing Record 33 of Set 7 | gilgit
# Processing Record 34 of Set 7 | temozon
# Processing Record 35 of Set 7 | suntar
# Processing Record 36 of Set 7 | upanema
# Processing Record 37 of Set 7 | loikaw
# Processing Record 38 of Set 7 | khovu-aksy
# Processing Record 39 of Set 7 | makakilo city
# Processing Record 40 of Set 7 | pasni
# Processing Record 41 of Set 7 | humaita
# Processing Record 42 of Set 7 | iquique
# Processing Record 43 of Set 7 | porto nacional
# Processing Record 44 of Set 7 | faro
# Processing Record 45 of Set 7 | takanabe
# Processing Record 46 of Set 7 | nouadhibou
# Processing Record 47 of Set 7 | narrabri
# Processing Record 48 of Set 7 | wegrow
# Processing Record 49 of Set 7 | nuuk
# Processing Record 50 of Set 7 | khakhea
# Processing Record 1 of Set 8 | tevriz
# Processing Record 2 of Set 8 | veraval
# Processing Record 3 of Set 8 | karratha
# Processing Record 4 of Set 8 | college
# Processing Record 5 of Set 8 | ayni
# Processing Record 6 of Set 8 | jalu
# Processing Record 7 of Set 8 | kiama
# Processing Record 8 of Set 8 | zakopane
# Processing Record 9 of Set 8 | saldanha
# Processing Record 10 of Set 8 | verkh-usugli
# Processing Record 11 of Set 8 | punuare
# Processing Record 12 of Set 8 | khash
# Processing Record 13 of Set 8 | bryant
# Processing Record 14 of Set 8 | iranshahr
# Processing Record 15 of Set 8 | athabasca
# Processing Record 16 of Set 8 | vila velha
# Processing Record 17 of Set 8 | leh
# Processing Record 18 of Set 8 | nome
# Processing Record 19 of Set 8 | zilina
# Processing Record 20 of Set 8 | macusani
# Processing Record 21 of Set 8 | mlandizi
# Processing Record 22 of Set 8 | te anau
# Processing Record 23 of Set 8 | geraldton
# Processing Record 24 of Set 8 | zhigansk
# Processing Record 25 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 8 | jardim de piranhas
# Processing Record 27 of Set 8 | ryotsu
# Processing Record 28 of Set 8 | gaogou
# Processing Record 29 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 30 of Set 8 | sao domingos do maranhao
# Processing Record 31 of Set 8 | young
# Processing Record 32 of Set 8 | quatre cocos
# Processing Record 33 of Set 8 | maragogi
# Processing Record 34 of Set 8 | amga
# Processing Record 35 of Set 8 | bam
# Processing Record 36 of Set 8 | san luis
# Processing Record 37 of Set 8 | xuanhua
# Processing Record 38 of Set 8 | novokayakent
# Processing Record 39 of Set 8 | shubarshi
# Processing Record 40 of Set 8 | sinnamary
# Processing Record 41 of Set 8 | tupancireta
# Processing Record 42 of Set 8 | uvat
# Processing Record 43 of Set 8 | ilula
# Processing Record 44 of Set 8 | dakar
# Processing Record 45 of Set 8 | muravlenko
# Processing Record 46 of Set 8 | esperance
# Processing Record 47 of Set 8 | port hardy
# Processing Record 48 of Set 8 | qixingtai
# Processing Record 49 of Set 8 | clonakilty
# Processing Record 50 of Set 8 | mikhaylovka
# Processing Record 1 of Set 9 | guerrero negro
# Processing Record 2 of Set 9 | ouadda
# Processing Record 3 of Set 9 | emba
# Processing Record 4 of Set 9 | nicoya
# Processing Record 5 of Set 9 | penzance
# Processing Record 6 of Set 9 | tuggurt
# City not found. Skipping...
# Processing Record 7 of Set 9 | zhanatas
# City not found. Skipping...
# Processing Record 8 of Set 9 | cachoeiras de macacu
# Processing Record 9 of Set 9 | jasper
# Processing Record 10 of Set 9 | anloga
# Processing Record 11 of Set 9 | itarema
# Processing Record 12 of Set 9 | haines junction
# Processing Record 13 of Set 9 | pedasi
# Processing Record 14 of Set 9 | severo-kurilsk
# Processing Record 15 of Set 9 | hirtshals
# Processing Record 16 of Set 9 | barra dos coqueiros
# Processing Record 17 of Set 9 | bowen
# Processing Record 18 of Set 9 | jiblah
# Processing Record 19 of Set 9 | santa marta de tormes
# Processing Record 20 of Set 9 | lompoc
# Processing Record 21 of Set 9 | lorengau
# Processing Record 22 of Set 9 | bagan
# Processing Record 23 of Set 9 | port blair
# Processing Record 24 of Set 9 | panguna
# Processing Record 25 of Set 9 | shchelyayur
# City not found. Skipping...
# Processing Record 26 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 9 | eenhana
# Processing Record 28 of Set 9 | shitanjing
# Processing Record 29 of Set 9 | laguna
# Processing Record 30 of Set 9 | aquiraz
# Processing Record 31 of Set 9 | galveston
# Processing Record 32 of Set 9 | pizarro
# Processing Record 33 of Set 9 | tura
# Processing Record 34 of Set 9 | paamiut
# Processing Record 35 of Set 9 | san ramon
# Processing Record 36 of Set 9 | lima
# Processing Record 37 of Set 9 | asau
# Processing Record 38 of Set 9 | richards bay
# Processing Record 39 of Set 9 | biak
# Processing Record 40 of Set 9 | westport
# Processing Record 41 of Set 9 | grande prairie
# Processing Record 42 of Set 9 | thinadhoo
# Processing Record 43 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 44 of Set 9 | yakeshi
# Processing Record 45 of Set 9 | bontang
# Processing Record 46 of Set 9 | kalabo
# Processing Record 47 of Set 9 | tautira
# Processing Record 48 of Set 9 | dunedin
# Processing Record 49 of Set 9 | grindavik
# Processing Record 50 of Set 9 | guiratinga
# Processing Record 1 of Set 10 | fort nelson
# Processing Record 2 of Set 10 | puerto del rosario
# Processing Record 3 of Set 10 | makamba
# Processing Record 4 of Set 10 | buta
# Processing Record 5 of Set 10 | port macquarie
# Processing Record 6 of Set 10 | sosnogorsk
# Processing Record 7 of Set 10 | hambantota
# Processing Record 8 of Set 10 | ha tinh
# Processing Record 9 of Set 10 | saryozek
# Processing Record 10 of Set 10 | honningsvag
# Processing Record 11 of Set 10 | chapais
# Processing Record 12 of Set 10 | dullewala
# Processing Record 13 of Set 10 | togur
# Processing Record 14 of Set 10 | canon city
# Processing Record 15 of Set 10 | meulaboh
# Processing Record 16 of Set 10 | kilinochchi
# Processing Record 17 of Set 10 | polovinnoye
# Processing Record 18 of Set 10 | sambava
# Processing Record 19 of Set 10 | muli
# Processing Record 20 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 10 | mugur-aksy
# Processing Record 22 of Set 10 | amurzet
# Processing Record 23 of Set 10 | ushibuka
# Processing Record 24 of Set 10 | kedgwick
# Processing Record 25 of Set 10 | tricase
# Processing Record 26 of Set 10 | atar
# Processing Record 27 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 28 of Set 10 | hornepayne
# Processing Record 29 of Set 10 | nelson
# Processing Record 30 of Set 10 | dong hoi
# Processing Record 31 of Set 10 | hami
# Processing Record 32 of Set 10 | madison heights
# Processing Record 33 of Set 10 | sauda
# Processing Record 34 of Set 10 | borogontsy
# Processing Record 35 of Set 10 | maceio
# Processing Record 36 of Set 10 | aklavik
# Processing Record 37 of Set 10 | tommot
# Processing Record 38 of Set 10 | buchanan
# Processing Record 39 of Set 10 | norrtalje
# Processing Record 40 of Set 10 | conceicao das alagoas
# Processing Record 41 of Set 10 | shingu
# Processing Record 42 of Set 10 | nara
# Processing Record 43 of Set 10 | mayo
# Processing Record 44 of Set 10 | goderich
# Processing Record 45 of Set 10 | ginda
# Processing Record 46 of Set 10 | kahului
# Processing Record 47 of Set 10 | cleburne
# Processing Record 48 of Set 10 | taltal
# Processing Record 49 of Set 10 | charlestown
# Processing Record 50 of Set 10 | arica
# Processing Record 1 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 11 | dongsheng
# Processing Record 3 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 4 of Set 11 | kavaratti
# Processing Record 5 of Set 11 | boguchany
# Processing Record 6 of Set 11 | gamba
# Processing Record 7 of Set 11 | okhotsk
# Processing Record 8 of Set 11 | sherbakul
# Processing Record 9 of Set 11 | ulladulla
# Processing Record 10 of Set 11 | vallenar
# Processing Record 11 of Set 11 | sechura
# Processing Record 12 of Set 11 | banmo
# City not found. Skipping...
# Processing Record 13 of Set 11 | butembo
# Processing Record 14 of Set 11 | batticaloa
# Processing Record 15 of Set 11 | kutum
# Processing Record 16 of Set 11 | chake chake
# Processing Record 17 of Set 11 | suao
# City not found. Skipping...
# Processing Record 18 of Set 11 | mendahara
# City not found. Skipping...
# Processing Record 19 of Set 11 | cam pha
# City not found. Skipping...
# Processing Record 20 of Set 11 | marawi
# Processing Record 21 of Set 11 | seminole
# Processing Record 22 of Set 11 | arcata
# Processing Record 23 of Set 11 | abha
# Processing Record 24 of Set 11 | traverse city
# Processing Record 25 of Set 11 | brigham city
# Processing Record 26 of Set 11 | liku
# Processing Record 27 of Set 11 | vaitape
# Processing Record 28 of Set 11 | saint-joseph
# Processing Record 29 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 30 of Set 11 | tual
# Processing Record 31 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 32 of Set 11 | belyy yar
# Processing Record 33 of Set 11 | kajaani
# Processing Record 34 of Set 11 | leshukonskoye
# Processing Record 35 of Set 11 | ancud
# Processing Record 36 of Set 11 | sao felix do xingu
# Processing Record 37 of Set 11 | anito
# Processing Record 38 of Set 11 | uporovo
# Processing Record 39 of Set 11 | labuhan
# Processing Record 40 of Set 11 | meadow lake
# Processing Record 41 of Set 11 | oranjemund
# Processing Record 42 of Set 11 | mtambile
# Processing Record 43 of Set 11 | tamworth
# Processing Record 44 of Set 11 | kandrian
# Processing Record 45 of Set 11 | tashtyp
# Processing Record 46 of Set 11 | ketchikan
# Processing Record 47 of Set 11 | kontagora
# Processing Record 48 of Set 11 | qaqortoq
# Processing Record 49 of Set 11 | baruun-urt
# Processing Record 50 of Set 11 | sampit
# Processing Record 1 of Set 12 | oxford
# Processing Record 2 of Set 12 | kano
# Processing Record 3 of Set 12 | bonthe
# Processing Record 4 of Set 12 | zenzeli
# Processing Record 5 of Set 12 | pipri
# Processing Record 6 of Set 12 | tocopilla
# Processing Record 7 of Set 12 | konitsa
# Processing Record 8 of Set 12 | sassandra
# Processing Record 9 of Set 12 | krasnovishersk
# Processing Record 10 of Set 12 | kevsala
# Processing Record 11 of Set 12 | digha
# Processing Record 12 of Set 12 | warrington
# Processing Record 13 of Set 12 | sidi ali
# Processing Record 14 of Set 12 | beeville
# Processing Record 15 of Set 12 | marabba
# Processing Record 16 of Set 12 | champerico
# Processing Record 17 of Set 12 | dubti
# Processing Record 18 of Set 12 | buraydah
# Processing Record 19 of Set 12 | leshan
# Processing Record 20 of Set 12 | north little rock
# Processing Record 21 of Set 12 | shadrinsk
# Processing Record 22 of Set 12 | guayaramerin
# Processing Record 23 of Set 12 | kampot
# Processing Record 24 of Set 12 | golden
# Processing Record 25 of Set 12 | manuk mangkaw
# Processing Record 26 of Set 12 | touros
# Processing Record 27 of Set 12 | khryashchevka
# Processing Record 28 of Set 12 | bokoro
# Processing Record 29 of Set 12 | nadym
# Processing Record 30 of Set 12 | ust-maya
# Processing Record 31 of Set 12 | zatoka
# Processing Record 32 of Set 12 | haysville
# Processing Record 33 of Set 12 | stoyba
# City not found. Skipping...
# Processing Record 34 of Set 12 | rodrigues alves
# Processing Record 35 of Set 12 | nurota
# Processing Record 36 of Set 12 | neringa
# Processing Record 37 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 12 | ilovlya
# Processing Record 39 of Set 12 | okany
# Processing Record 40 of Set 12 | pauini
# Processing Record 41 of Set 12 | plainview
# Processing Record 42 of Set 12 | xingyi
# Processing Record 43 of Set 12 | ciudad barrios
# Processing Record 44 of Set 12 | havre
# Processing Record 45 of Set 12 | lasa
# Processing Record 46 of Set 12 | donji milanovac
# Processing Record 47 of Set 12 | san andres
# Processing Record 48 of Set 12 | beyneu
# Processing Record 49 of Set 12 | lengshuitan
# Processing Record 50 of Set 12 | nabire
# Processing Record 1 of Set 13 | normandin
# Processing Record 2 of Set 13 | najran
# Processing Record 3 of Set 13 | bahia honda
# Processing Record 4 of Set 13 | shahpur chakar
# Processing Record 5 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 13 | sol-iletsk
# Processing Record 7 of Set 13 | boyolangu
# Processing Record 8 of Set 13 | saint-francois
# Processing Record 9 of Set 13 | nyzhni sirohozy
# Processing Record 10 of Set 13 | puerto maldonado
# Processing Record 11 of Set 13 | katsuura
# Processing Record 12 of Set 13 | krasnovka
# Processing Record 13 of Set 13 | guarapari
# Processing Record 14 of Set 13 | akyab
# Processing Record 15 of Set 13 | nehe
# Processing Record 16 of Set 13 | vao
# Processing Record 17 of Set 13 | comodoro rivadavia
# Processing Record 18 of Set 13 | ambon
# Processing Record 19 of Set 13 | ayan
# Processing Record 20 of Set 13 | kedrovyy
# Processing Record 21 of Set 13 | prince rupert
# Processing Record 22 of Set 13 | mount isa
# Processing Record 23 of Set 13 | charleston
# Processing Record 24 of Set 13 | ballina
# Processing Record 25 of Set 13 | sur
# Processing Record 26 of Set 13 | key largo
# Processing Record 27 of Set 13 | skaerbaek
# Processing Record 28 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 13 | uri
# Processing Record 30 of Set 13 | balkhash
# Processing Record 31 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 32 of Set 13 | waddan
# Processing Record 33 of Set 13 | isiolo
# Processing Record 34 of Set 13 | sainte-rose
# Processing Record 35 of Set 13 | beloha
# Processing Record 36 of Set 13 | khandbari
# Processing Record 37 of Set 13 | almaznyy
# Processing Record 38 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 39 of Set 13 | kuytun
# Processing Record 40 of Set 13 | santa maria
# Processing Record 41 of Set 13 | baker city
# Processing Record 42 of Set 13 | wasilla
# Processing Record 43 of Set 13 | bairiki
# Processing Record 44 of Set 13 | staryy nadym
# Processing Record 45 of Set 13 | pangnirtung
# Processing Record 46 of Set 13 | lagos
# Processing Record 47 of Set 13 | terra roxa
# Processing Record 48 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 49 of Set 13 | ullapool
# Processing Record 50 of Set 13 | newport
# Processing Record 1 of Set 14 | omboue
# Processing Record 2 of Set 14 | porbandar
# Processing Record 3 of Set 14 | segamat
# Processing Record 4 of Set 14 | katherine
# Processing Record 5 of Set 14 | zeya
# Processing Record 6 of Set 14 | taoudenni
# Processing Record 7 of Set 14 | shenjiamen
# Processing Record 8 of Set 14 | silvania
# Processing Record 9 of Set 14 | kijang
# Processing Record 10 of Set 14 | deputatskiy
# Processing Record 11 of Set 14 | san cristobal
# Processing Record 12 of Set 14 | bahia blanca
# Processing Record 13 of Set 14 | klyuchi
# Processing Record 14 of Set 14 | volot
# Processing Record 15 of Set 14 | nobeoka
# Processing Record 16 of Set 14 | brightwater
# Processing Record 17 of Set 14 | zaysan
# Processing Record 18 of Set 14 | pilar
# Processing Record 19 of Set 14 | trinidad
# Processing Record 20 of Set 14 | aybak
# City not found. Skipping...
# Processing Record 21 of Set 14 | la ronge
# Processing Record 22 of Set 14 | chippewa falls
# Processing Record 23 of Set 14 | periyapatti
# Processing Record 24 of Set 14 | yirol
# City not found. Skipping...
# Processing Record 25 of Set 14 | poladpur
# Processing Record 26 of Set 14 | buala
# Processing Record 27 of Set 14 | acarau
# Processing Record 28 of Set 14 | bama
# Processing Record 29 of Set 14 | marovoay
# Processing Record 30 of Set 14 | surdila-gaiseanca
# Processing Record 31 of Set 14 | bom sucesso
# Processing Record 32 of Set 14 | olinda
# Processing Record 33 of Set 14 | correntina
# Processing Record 34 of Set 14 | morondava
# Processing Record 35 of Set 14 | mahon
# Processing Record 36 of Set 14 | petukhovo
# Processing Record 37 of Set 14 | melipilla
# Processing Record 38 of Set 14 | slavgorodskoye
# Processing Record 39 of Set 14 | ossora
# Processing Record 40 of Set 14 | falun
# Processing Record 41 of Set 14 | hukeri
# Processing Record 42 of Set 14 | badvel
# Processing Record 43 of Set 14 | cuiluan
# Processing Record 44 of Set 14 | luwuk
# Processing Record 45 of Set 14 | kindu
# Processing Record 46 of Set 14 | kununurra
# Processing Record 47 of Set 14 | kothi
# Processing Record 48 of Set 14 | narodychi
# Processing Record 49 of Set 14 | mormugao
# Processing Record 50 of Set 14 | silyanah
# City not found. Skipping...
# Processing Record 1 of Set 15 | baboua
# City not found. Skipping...
# Processing Record 2 of Set 15 | umea
# Processing Record 3 of Set 15 | cabedelo
# Processing Record 4 of Set 15 | puerto quijarro
# Processing Record 5 of Set 15 | seoul
# Processing Record 6 of Set 15 | garowe
# Processing Record 7 of Set 15 | camana
# Processing Record 8 of Set 15 | orlik
# Processing Record 9 of Set 15 | minab
# Processing Record 10 of Set 15 | kupang
# Processing Record 11 of Set 15 | katha
# City not found. Skipping...
# Processing Record 12 of Set 15 | olga
# Processing Record 13 of Set 15 | axim
# Processing Record 14 of Set 15 | sciacca
# Processing Record 15 of Set 15 | moskovskiy
# Processing Record 16 of Set 15 | bud
# Processing Record 17 of Set 15 | kemi
# Processing Record 18 of Set 15 | mullaitivu
# City not found. Skipping...
# Processing Record 19 of Set 15 | knysna
# Processing Record 20 of Set 15 | armidale
# Processing Record 21 of Set 15 | wau
# Processing Record 22 of Set 15 | arcachon
# Processing Record 23 of Set 15 | bolshoy uluy
# City not found. Skipping...
# Processing Record 24 of Set 15 | robertsport
# Processing Record 25 of Set 15 | pahrump
# Processing Record 26 of Set 15 | harnosand
# Processing Record 27 of Set 15 | abeche
# Processing Record 28 of Set 15 | kazachinskoye
# Processing Record 29 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 30 of Set 15 | saint-denis
# Processing Record 31 of Set 15 | vad
# Processing Record 32 of Set 15 | muisne
# Processing Record 33 of Set 15 | zaigrayevo
# Processing Record 34 of Set 15 | alto araguaia
# Processing Record 35 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 36 of Set 15 | mehamn
# Processing Record 37 of Set 15 | kamyshin
# Processing Record 38 of Set 15 | tanggu
# Processing Record 39 of Set 15 | kamaishi
# Processing Record 40 of Set 15 | agirish
# Processing Record 41 of Set 15 | banda aceh
# Processing Record 42 of Set 15 | da lat
# Processing Record 43 of Set 15 | solsvik
# City not found. Skipping...
# Processing Record 44 of Set 15 | zhangye
# Processing Record 45 of Set 15 | sitio novo do tocantins
# Processing Record 46 of Set 15 | vila
# Processing Record 47 of Set 15 | bayamo
# Processing Record 48 of Set 15 | green river
# Processing Record 49 of Set 15 | ylojarvi
# Processing Record 50 of Set 15 | tigre
# Processing Record 1 of Set 16 | utiroa
# City not found. Skipping...
# Processing Record 2 of Set 16 | fereydunshahr
# Processing Record 3 of Set 16 | hobyo
# Processing Record 4 of Set 16 | smithers
# Processing Record 5 of Set 16 | si chiang mai
# Processing Record 6 of Set 16 | da nang
# Processing Record 7 of Set 16 | sidi bu zayd
# City not found. Skipping...
# Processing Record 8 of Set 16 | elliot lake
# Processing Record 9 of Set 16 | miram shah
# Processing Record 10 of Set 16 | ayagoz
# Processing Record 11 of Set 16 | illapel
# Processing Record 12 of Set 16 | murighiol
# Processing Record 13 of Set 16 | sabang
# Processing Record 14 of Set 16 | union de san antonio
# Processing Record 15 of Set 16 | presidente dutra
# Processing Record 16 of Set 16 | vagur
# Processing Record 17 of Set 16 | orje
# Processing Record 18 of Set 16 | chimore
# Processing Record 19 of Set 16 | livny
# Processing Record 20 of Set 16 | namatanai
# Processing Record 21 of Set 16 | the valley
# Processing Record 22 of Set 16 | florence
# Processing Record 23 of Set 16 | inirida
# Processing Record 24 of Set 16 | turukhansk
# Processing Record 25 of Set 16 | abeokuta
# Processing Record 26 of Set 16 | porto de moz
# Processing Record 27 of Set 16 | santa cruz
# Processing Record 28 of Set 16 | la rioja
# Processing Record 29 of Set 16 | sao jose da coroa grande
# Processing Record 30 of Set 16 | ukiah
# Processing Record 31 of Set 16 | ambilobe
# Processing Record 32 of Set 16 | honiara
# Processing Record 33 of Set 16 | sayat
# Processing Record 34 of Set 16 | alyangula
# Processing Record 35 of Set 16 | doha
# Processing Record 36 of Set 16 | mossingen
# Processing Record 37 of Set 16 | tucuman
# Processing Record 38 of Set 16 | mount darwin
# Processing Record 39 of Set 16 | las vegas
# Processing Record 40 of Set 16 | jorochito
# Processing Record 41 of Set 16 | gondanglegi
# Processing Record 42 of Set 16 | pasir gudang
# Processing Record 43 of Set 16 | naryan-mar
# Processing Record 44 of Set 16 | sadiqabad
# Processing Record 45 of Set 16 | chegdomyn
# Processing Record 46 of Set 16 | ivybridge
# Processing Record 47 of Set 16 | vysokogornyy
# Processing Record 48 of Set 16 | sanming
# Processing Record 49 of Set 16 | trapani
# Processing Record 50 of Set 16 | yunhe
# Processing Record 1 of Set 17 | oum hadjer
# Processing Record 2 of Set 17 | nanzhang
# Processing Record 3 of Set 17 | san antonio
# Processing Record 4 of Set 17 | constantine
# Processing Record 5 of Set 17 | george
# Processing Record 6 of Set 17 | soyo
# Processing Record 7 of Set 17 | karaul
# City not found. Skipping...
# Processing Record 8 of Set 17 | paola
# Processing Record 9 of Set 17 | saint-augustin
# Processing Record 10 of Set 17 | nishihara
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df=pd.DataFrame(city_data)
new_column_order=['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed','Current Description']
city_data_df=city_data_df[new_column_order]
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0       Primo Tapia      MX  32.2200 -116.9172     62.22        71
# 1              Kang      BW -23.6752   22.7876     56.08        79
# 2         Busselton      AU -33.6500  115.3333     64.04        90
# 3           Rikitea      PF -23.1203 -134.9692     75.49        73
# 4          Victoria      HK  22.2855  114.1577     83.97        67
# ..              ...     ...      ...       ...       ...       ...
# 742          George      ZA -33.9630   22.4617     44.15        93
# 743            Soyo      AO  -6.1349   12.3689     75.52        81
# 744           Paola      IT  39.3599   16.0396     51.01        77
# 745  Saint-Augustin      CA  51.2260  -58.6502     44.17        97
# 746       Nishihara      JP  26.1842  127.7558     76.66        83
#
#      Cloudiness  Wind Speed Current Description
# 0            42        6.26    scattered clouds
# 1            97       13.56     overcast clouds
# 2           100       26.69     overcast clouds
# 3            14       20.98          few clouds
# 4            74        3.00       broken clouds
# ..          ...         ...                 ...
# 742           0        2.30           clear sky
# 743         100        6.55     overcast clouds
# 744          18        7.07          few clouds
# 745         100       26.91     overcast clouds
# 746          75       20.71       broken clouds
#
# [747 rows x 9 columns]

# %%
output_data_file='weather_data/WeatherPy_Database.csv'
city_data_df.to_csv(output_data_file,index_label='City_ID')
